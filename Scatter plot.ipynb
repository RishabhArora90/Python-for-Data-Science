# %%
import pandas as pd 
file1=pd.read_csv("C:\\Users\\arora\\Desktop\\R Directory\\Try.csv")
file1

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1= pd.DataFrame({"Name":['Rishabh','Jack','Tim', 'Jade','Jack','Dexter', 'Jack'], "Age":[24,26,28,37,56,67,76], "Weight":[68,74,78,80,87,76,85], "Gender":['M','M','M','F','M','M','M'],"Place":["Philadelphia","Columbia", "California","Chicago","Austin", "Dallas","Michigan"]})
file1
file1["Name"]
file1.head(10)
file2=file1.set_index("Name")
file2
#file2.loc["Rishabh":"Jack"]
#file2.loc["Jack":"Tim",["Age","Place"]]
file2.iloc[2:4,[0]]
file1.plot()
file1.plot(kind="bar")
file1.plot.scatter(x="Age",y="Weight")
groupfile=file1.groupby("Name")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
